# %% [markdown]
# # Objective
# Main Task is to understand food insecurities from the given news articles. Secondary to it, but most likely critical, is to find a way to predict food insecurities given the limited data.
#
# * It seems I am also allowed to work with external (open) data sources as long as I document and provide it properly.
#
# ### Open Questions:
# * What does it mean to understand food insecurities. What kind of insights can I extract from the data that add to understanding of food insecurities?
# * I could assume what I can extract from the articles are potentially frequent location of food insecurities and potentially the context in which they occur - for instance, are they frequently mentioned along some conflict or other geopolitical occcurence - how would I extract this in a statistically sound way? Would co-occurence in the text be enough or would I need to ensure they are also semantically linked - how to do that?

# %% [markdown]
# # Data Considerations
# * I wonder if the english risk-factors in the excel with missing arabic translations are the same as the risk factors keywords in the category excel - I will check this. If not - I wonder if I should try to add them under the risk factor categories as well.
# * How will I make best of the clusters?
# * Arabic risk-factors are not given and hence I have to use some translation API here. Probably google translation API to keep it simple, or some LLM call.
# * I have geospatial information of specific locations - this will help to map/visualise hotspots or frequently occuring/mentioned places related to food insecurities?
# * The time series aspect of news article seems important - especially, when we are looking into predicting (early warning signs) of food insecurities.
#
# Some example questions to consider:
# - What is the added value of geospatial data?
# - How can we address the lack of ground-truth information on food insecurity levels?
# - What are the benefits and challenges of working with multilingual data?
# - ...
#
# ### Open Questions:
# * How to make best use of clusters and keywords?
# * How to make best of location data?
# * How to account for the time series component of the news article?

# %% [markdown]
# # Technical Steps and Considerations
# * Create virtual environment and req.txt for reprodudibility
# * Keep folder structure and notebooks clean and simple - create src folder for helper functions (data loading, cleaning, etc), create img folder for storing graphs, images. And so on...
# * I will try to use the notebooks to explore the data and tasks and then write clean functions and put them in src to execute the analysis cleanly in the technical-assessment.ipynb
